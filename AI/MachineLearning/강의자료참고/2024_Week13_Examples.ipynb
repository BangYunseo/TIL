# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import dendrogram, linkage

x_train = np.array([[18,5], [20,9], [20,14], [20,17], [5,15], [9,15], [6,20]])

dist_p = squareform(pdist(x_train))
print("Distance b/w samples:", pdist(x_train))

print("Distance b/w samples:", dist_p)


Z = linkage(x_train, 'complete') # single: Dmin, complete: Dmax, average: Davg

print(Z)

fig = plt.figure(figsize=(25, 10))
dn = dendrogram(Z)
plt.show()
# Out:
# Distance b/w samples: [ 4.47213595  9.21954446 12.16552506 16.40121947 13.45362405 19.20937271
#   5.          8.         16.15549442 12.52996409 17.80449381  3.
#  15.03329638 11.04536102 15.23154621 15.13274595 11.18033989 14.31782106
#   4.          5.09901951  5.83095189]
# Distance b/w samples: [[ 0.          4.47213595  9.21954446 12.16552506 16.40121947 13.45362405
#   19.20937271]
#  [ 4.47213595  0.          5.          8.         16.15549442 12.52996409
#   17.80449381]
#  [ 9.21954446  5.          0.          3.         15.03329638 11.04536102
#   15.23154621]
#  [12.16552506  8.          3.          0.         15.13274595 11.18033989
#   14.31782106]
#  [16.40121947 16.15549442 15.03329638 15.13274595  0.          4.
#    5.09901951]
#  [13.45362405 12.52996409 11.04536102 11.18033989  4.          0.
#    5.83095189]
#  [19.20937271 17.80449381 15.23154621 14.31782106  5.09901951  5.83095189
#    0.        ]]
# [[ 2.          3.          3.          2.        ]
#  [ 4.          5.          4.          2.        ]
#  [ 0.          1.          4.47213595  2.        ]
#  [ 6.          8.          5.83095189  3.        ]
#  [ 7.          9.         12.16552506  4.        ]
#  [10.         11.         19.20937271  7.        ]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering

x_train = np.array([[18,5], [20,9], [20,14], [20,17], [5,15], [9,15], [6,20]])

cluster_single = AgglomerativeClustering(n_clusters=3, metric='euclidean', linkage='single')
y_single = cluster_single.fit_predict(x_train)

print(y_single)

plt.title("Clustering with single-linkage")
plt.plot(x_train[y_single==0, 0], x_train[y_single==0, 1], 'ro')
plt.plot(x_train[y_single==1, 0], x_train[y_single==1, 1], 'bs')
plt.plot(x_train[y_single==2, 0], x_train[y_single==2, 1], 'g^')
plt.grid(True)
plt.show()
# Out:
# [1 1 2 2 0 0 0]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import dendrogram, linkage

x_train = np.array([[18,5], [20,9], [20,14], [20,17], [5,15], [9,15], [6,20]])

dist_p = squareform(pdist(x_train))

print(dist_p)

Z = linkage(x_train, 'complete')

print(Z)

fig = plt.figure(figsize=(25, 10))
dn = dendrogram(Z)
plt.show()

cluster_complete = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='complete')
y_complete = cluster_complete.fit_predict(x_train)

print(y_complete)

plt.title("Clustering with complete-linkage")
plt.plot(x_train[y_complete==0, 0], x_train[y_complete==0, 1], 'ro')
plt.plot(x_train[y_complete==1, 0], x_train[y_complete==1, 1], 'bs')
plt.plot(x_train[y_complete==2, 0], x_train[y_complete==2, 1], 'g^')
plt.grid(True)
plt.show()
# Out:
# [[ 0.          4.47213595  9.21954446 12.16552506 16.40121947 13.45362405
#   19.20937271]
#  [ 4.47213595  0.          5.          8.         16.15549442 12.52996409
#   17.80449381]
#  [ 9.21954446  5.          0.          3.         15.03329638 11.04536102
#   15.23154621]
#  [12.16552506  8.          3.          0.         15.13274595 11.18033989
#   14.31782106]
#  [16.40121947 16.15549442 15.03329638 15.13274595  0.          4.
#    5.09901951]
#  [13.45362405 12.52996409 11.04536102 11.18033989  4.          0.
#    5.83095189]
#  [19.20937271 17.80449381 15.23154621 14.31782106  5.09901951  5.83095189
#    0.        ]]
# [[ 2.          3.          3.          2.        ]
#  [ 4.          5.          4.          2.        ]
#  [ 0.          1.          4.47213595  2.        ]
#  [ 6.          8.          5.83095189  3.        ]
#  [ 7.          9.         12.16552506  4.        ]
#  [10.         11.         19.20937271  7.        ]]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# [1 1 2 2 0 0 0]

# %%
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt

x_train = np.array([[18,5], [20,9], [20,14], [20,17], [5,15], [9,15], [6,20]])

Z = linkage(x_train, 'complete')

print(Z)

fig = plt.figure(figsize=(25, 10))
dn = dendrogram(Z)
plt.show()
# Out:
# [[ 2.          3.          3.          2.        ]
#  [ 4.          5.          4.          2.        ]
#  [ 0.          1.          4.47213595  2.        ]
#  [ 6.          8.          5.83095189  3.        ]
#  [ 7.          9.         12.16552506  4.        ]
#  [10.         11.         19.20937271  7.        ]]

# %% [markdown]
# **Example of SOM algorithm**

# %%
import numpy as np
import matplotlib.pyplot as plt

x_train = np.array([[18,5], [20,9], [20,14], [20,17], [5,15], [9,15], [6,20]])
init_w = np.array([[10.0, 12.0], [6.0, 6.0], [16.0, 14.0]])
comp = np.array([0.0, 0.0, 0.0])

rho = 0.6

for i in range(7):
    print('====================================')
    print('Sample index:',i)
    for j in range(3):
        comp[j] = np.linalg.norm(x_train[i,:] - init_w[j,:])

    print('Distance between vectors and sample:', comp)
    idx = np.argmin(comp)
    print('Index of vector with minimum distance:', idx)
    init_w[idx,:] = init_w[idx,:] + rho*(x_train[i,:] - init_w[idx,:])
    print('Updated vectors:', '\n', init_w)
# Out:
# ====================================
# Sample index: 0
# Distance between vectors and sample: [10.63014581 12.04159458  9.21954446]
# Index of vector with minimum distance: 2
# Updated vectors:
#  [[10.  12. ]
#  [ 6.   6. ]
#  [17.2  8.6]]
# ====================================
# Sample index: 1
# Distance between vectors and sample: [10.44030651 14.31782106  2.82842712]
# Index of vector with minimum distance: 2
# Updated vectors:
#  [[10.   12.  ]
#  [ 6.    6.  ]
#  [18.88  8.84]]
# ====================================
# Sample index: 2
# Distance between vectors and sample: [10.19803903 16.1245155   5.28015151]
# Index of vector with minimum distance: 2
# Updated vectors:
#  [[10.    12.   ]
#  [ 6.     6.   ]
#  [19.552 11.936]]
# ====================================
# Sample index: 3
# Distance between vectors and sample: [11.18033989 17.80449381  5.08377812]
# Index of vector with minimum distance: 2
# Updated vectors:
#  [[10.     12.    ]
#  [ 6.      6.    ]
#  [19.8208 14.9744]]
# ====================================
# Sample index: 4
# Distance between vectors and sample: [ 5.83095189  9.05538514 14.82082211]
# Index of vector with minimum distance: 0
# Updated vectors:
#  [[ 7.     13.8   ]
#  [ 6.      6.    ]
#  [19.8208 14.9744]]
# ====================================
# Sample index: 5
# Distance between vectors and sample: [ 2.33238076  9.48683298 10.82083028]
# Index of vector with minimum distance: 0
# Updated vectors:
#  [[ 8.2    14.52  ]
#  [ 6.      6.    ]
#  [19.8208 14.9744]]
# ====================================
# Sample index: 6
# Distance between vectors and sample: [ 5.90511643 14.         14.70616089]
# Index of vector with minimum distance: 0
# Updated vectors:
#  [[ 6.88   17.808 ]
#  [ 6.      6.    ]
#  [19.8208 14.9744]]
