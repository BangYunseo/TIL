# %% [markdown]
# Example for k-means

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster
from sklearn.cluster import KMeans

x_train = np.array([[18,5], [20,9], [20,14], [20,17], [5,15], [9,15], [6,20]])

plt.axis([0, 22, 0, 22])
plt.plot(x_train[:, 0], x_train[:, 1], 'ro')
plt.grid(True)
plt.show()

kmeans = KMeans(n_clusters=4, n_init='auto')
kmeans.fit(x_train)

y = kmeans.labels_

print('Clustering:',y)

plt.axis([0, 22, 0, 22])
plt.plot(x_train[y==0, 0], x_train[y==0, 1], 'ro', x_train[y==1, 0], x_train[y==1, 1], 'bo', x_train[y==2, 0], x_train[y==2, 1], 'ko')
plt.grid(True)
plt.show()
# Out:
# Clustering: [2 2 0 0 3 3 1]

# %% [markdown]
# **Example for 12th week**

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster
from sklearn.cluster import KMeans

x_train = np.array([[18,5], [20,9], [20,14], [20,17], [5,15], [9,15], [6,20]])

plt.axis([0, 22, 0, 22])
plt.plot(x_train[:, 0], x_train[:, 1], 'ro')
plt.grid(True)
plt.show()

kmeans = KMeans(n_clusters=2, n_init='auto')
kmeans.fit(x_train)

y = kmeans.labels_

print('Clustering:',y)

plt.axis([0, 22, 0, 22])
plt.plot(x_train[y==0, 0], x_train[y==0, 1], 'ro', x_train[y==1, 0], x_train[y==1, 1], 'bo', x_train[y==2, 0], x_train[y==2, 1], 'ko')
plt.grid(True)
plt.show()
# Out:
# Clustering: [0 0 0 0 1 1 1]
